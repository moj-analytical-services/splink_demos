# %% [markdown]
# ## Linking a dataset of real historical persons
#
# In this example, we deduplicate a more realistic dataset.  The data is based on historical persons scraped from wikidata.  Duplicate records are introduced with a variety of errors introduced.

# %%
#%pip install -U splink
# %pip install -U altair_viewer
# Out:
# Requirement already satisfied: altair_viewer in /Users/rosskennedy/Library/r-miniconda/lib/python3.9/site-packages (0.4.0)
# Requirement already satisfied: altair-data-server>=0.4.0 in /Users/rosskennedy/Library/r-miniconda/lib/python3.9/site-packages (from altair_viewer) (0.4.1)
# Requirement already satisfied: altair in /Users/rosskennedy/Library/r-miniconda/lib/python3.9/site-packages (from altair_viewer) (5.0.1)
# Requirement already satisfied: tornado in /Users/rosskennedy/Library/r-miniconda/lib/python3.9/site-packages (from altair-data-server>=0.4.0->altair_viewer) (6.2)
# Requirement already satisfied: portpicker in /Users/rosskennedy/Library/r-miniconda/lib/python3.9/site-packages (from altair-data-server>=0.4.0->altair_viewer) (1.5.2)
# Requirement already satisfied: pandas>=0.18 in /Users/rosskennedy/Library/r-miniconda/lib/python3.9/site-packages (from altair->altair_viewer) (1.5.1)
# Requirement already satisfied: jinja2 in /Users/rosskennedy/Library/r-miniconda/lib/python3.9/site-packages (from altair->altair_viewer) (3.1.2)
# Requirement already satisfied: toolz in /Users/rosskennedy/Library/r-miniconda/lib/python3.9/site-packages (from altair->altair_viewer) (0.12.0)
# Requirement already satisfied: jsonschema>=3.0 in /Users/rosskennedy/Library/r-miniconda/lib/python3.9/site-packages (from altair->altair_viewer) (4.17.3)
# Requirement already satisfied: typing-extensions>=4.0.1 in /Users/rosskennedy/Library/r-miniconda/lib/python3.9/site-packages (from altair->altair_viewer) (4.6.3)
# Requirement already satisfied: numpy in /Users/rosskennedy/Library/r-miniconda/lib/python3.9/site-packages (from altair->altair_viewer) (1.23.4)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/rosskennedy/Library/r-miniconda/lib/python3.9/site-packages (from jsonschema>=3.0->altair->altair_viewer) (0.19.3)
# Requirement already satisfied: attrs>=17.4.0 in /Users/rosskennedy/Library/r-miniconda/lib/python3.9/site-packages (from jsonschema>=3.0->altair->altair_viewer) (22.2.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/rosskennedy/Library/r-miniconda/lib/python3.9/site-packages (from pandas>=0.18->altair->altair_viewer) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/rosskennedy/Library/r-miniconda/lib/python3.9/site-packages (from pandas>=0.18->altair->altair_viewer) (2.8.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/rosskennedy/Library/r-miniconda/lib/python3.9/site-packages (from jinja2->altair->altair_viewer) (2.1.2)
# Requirement already satisfied: psutil in /Users/rosskennedy/Library/r-miniconda/lib/python3.9/site-packages (from portpicker->altair-data-server>=0.4.0->altair_viewer) (5.9.2)
# Requirement already satisfied: six>=1.5 in /Users/rosskennedy/Library/r-miniconda/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas>=0.18->altair->altair_viewer) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from splink.duckdb.linker import DuckDBLinker
import altair as alt
alt.renderers.enable('html')

import pandas as pd 
pd.options.display.max_rows = 1000
df = pd.read_parquet("../../data/historical_figures_with_errors_50k.parquet")

# %%
# Simple settings dictionary will be used for exploratory analysis
settings = {
    "link_type": "dedupe_only",
    "blocking_rules_to_generate_predictions": [
        "l.first_name = r.first_name and l.surname = r.surname",
        "l.surname = r.surname and l.dob = r.dob",
        "l.first_name = r.first_name and l.dob = r.dob",
        "l.postcode_fake = r.postcode_fake and l.first_name = r.first_name",
    ],
}
linker = DuckDBLinker(df, settings)

linker.profile_columns(
    ["first_name", "postcode_fake", "substr(dob, 1,4)"], top_n=10, bottom_n=5
)
# Out:
# alt.VConcatChart(...)

# %%
linker.cumulative_num_comparisons_from_blocking_rules_chart()
# Out:
# alt.Chart(...)

# %%
import splink.duckdb.comparison_template_library as ctl
import splink.duckdb.comparison_library as cl

settings = {
    "link_type": "dedupe_only",
    "blocking_rules_to_generate_predictions": [
        "l.first_name = r.first_name and l.surname = r.surname",
        "l.surname = r.surname and l.dob = r.dob",
        "l.first_name = r.first_name and l.dob = r.dob",
        "l.postcode_fake = r.postcode_fake and l.first_name = r.first_name",
    ],
    "comparisons": [
        ctl.name_comparison("first_name", term_frequency_adjustments=True),
        ctl.name_comparison("surname", term_frequency_adjustments=True),
        cl.damerau_levenshtein_at_thresholds("dob", [1, 2], term_frequency_adjustments=True),
        ctl.postcode_comparison("postcode_fake"),
        cl.exact_match("birth_place", term_frequency_adjustments=True),
        cl.exact_match("occupation",  term_frequency_adjustments=True),
    ],
    "retain_matching_columns": True,
    "retain_intermediate_calculation_columns": True,
    "max_iterations": 10,
    "em_convergence": 0.01
}

linker = DuckDBLinker(df, settings)

# %%
linker.estimate_probability_two_random_records_match(
    [
        "l.first_name = r.first_name and l.surname = r.surname and l.dob = r.dob",
        "substr(l.first_name,1,2) = substr(r.first_name,1,2) and l.surname = r.surname and substr(l.postcode_fake,1,2) = substr(r.postcode_fake,1,2)",
        "l.dob = r.dob and l.postcode_fake = r.postcode_fake",
    ],
    recall=0.6,
)
# Out:
# Probability two random records match is estimated to be  0.000136.
# This means that amongst all possible pairwise record comparisons, one in 7,362.31 are expected to match.  With 1,279,041,753 total possible comparisons, we expect a total of around 173,728.33 matching pairs

# %%
linker.estimate_u_using_random_sampling(max_pairs=5e6)
# Out:
# ----- Estimating u probabilities using random sampling -----
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# Estimated u probabilities using random sampling
#
# Your model is not yet fully trained. Missing estimates for:
#     - first_name (no m values are trained).
#     - surname (no m values are trained).
#     - dob (no m values are trained).
#     - postcode_fake (no m values are trained).
#     - birth_place (no m values are trained).
#     - occupation (no m values are trained).

# %%
training_blocking_rule = "l.first_name = r.first_name and l.surname = r.surname"
training_session_names = linker.estimate_parameters_using_expectation_maximisation(training_blocking_rule)
# Out:
# ----- Starting EM training session -----
#
# Estimating the m probabilities of the model by blocking on:
# l.first_name = r.first_name and l.surname = r.surname
#
# Parameter estimates will be made for the following comparison(s):
#     - dob
#     - postcode_fake
#     - birth_place
#     - occupation
#
# Parameter estimates cannot be made for the following comparison(s) since they are used in the blocking rules:
#     - first_name
#     - surname
#
# Iteration 1: Largest change in params was -0.528 in probability_two_random_records_match
# Iteration 2: Largest change in params was -0.0363 in the m_probability of birth_place, level `All other comparisons`
# Iteration 3: Largest change in params was 0.012 in the m_probability of birth_place, level `Exact match`
# Iteration 4: Largest change in params was -0.00349 in the m_probability of birth_place, level `All other comparisons`
#
# EM converged after 4 iterations
#
# Your model is not yet fully trained. Missing estimates for:
#     - first_name (no m values are trained).
#     - surname (no m values are trained).

# %%
training_blocking_rule = "l.dob = r.dob"
training_session_dob = linker.estimate_parameters_using_expectation_maximisation(training_blocking_rule)
# Out:
# ----- Starting EM training session -----
#
# Estimating the m probabilities of the model by blocking on:
# l.dob = r.dob
#
# Parameter estimates will be made for the following comparison(s):
#     - first_name
#     - surname
#     - postcode_fake
#     - birth_place
#     - occupation
#
# Parameter estimates cannot be made for the following comparison(s) since they are used in the blocking rules:
#     - dob
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# Iteration 1: Largest change in params was -0.363 in the m_probability of first_name, level `Exact match first_name`
# Iteration 2: Largest change in params was 0.0416 in the m_probability of first_name, level `All other comparisons`
# Iteration 3: Largest change in params was 0.00779 in the m_probability of surname, level `All other comparisons`
#
# EM converged after 3 iterations
#
# Your model is fully trained. All comparisons have at least one estimate for their m and u values

# %% [markdown]
# The final match weights can be viewed in the match weights chart:

# %%
linker.match_weights_chart()
# Out:
# alt.VConcatChart(...)

# %%
linker.unlinkables_chart()
# Out:
# alt.LayerChart(...)

# %%
df_predict = linker.predict()
df_e = df_predict.as_pandas_dataframe(limit=5)
df_e
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
#    match_weight  match_probability  unique_id_l  unique_id_r first_name_l  \
# 0     13.210288           0.999894   Q2296770-1  Q2296770-14       thomas
# 1     40.007381           1.000000   Q1443188-1   Q1443188-3        frank
# 2     40.007381           1.000000   Q1443188-2   Q1443188-3        frank
# 3     40.955061           1.000000  Q90404618-1  Q90404618-3        emlie
# 4     40.955061           1.000000  Q90404618-2  Q90404618-3        emlie
#
#   first_name_r  gamma_first_name  tf_first_name_l  tf_first_name_r  \
# 0       thomas                 4         0.028667         0.028667
# 1        frank                 4         0.006335         0.006335
# 2        frank                 4         0.006335         0.006335
# 3        emlie                 4         0.000099         0.000099
# 4        emlie                 4         0.000099         0.000099
#
#    bf_first_name  ...  bf_birth_place bf_tf_adj_birth_place occupation_l  \
# 0      43.667835  ...        1.000000              1.000000   politician
# 1      43.667835  ...        0.154041              1.000000    liturgist
# 2      43.667835  ...        0.154041              1.000000    liturgist
# 3      43.667835  ...      175.290706              4.791965   playwright
# 4      43.667835  ...      175.290706              4.791965   playwright
#
#    occupation_r  gamma_occupation  tf_occupation_l  tf_occupation_r  \
# 0    politician                 1         0.088932         0.088932
# 1     liturgist                 1         0.000237         0.000237
# 2     liturgist                 1         0.000237         0.000237
# 3    playwright                 1         0.002728         0.002728
# 4    playwright                 1         0.002728         0.002728
#
#    bf_occupation bf_tf_adj_occupation match_key
# 0      23.448395             0.429542         0
# 1      23.448395           161.006691         0
# 2      23.448395           161.006691         0
# 3      23.448395            14.000582         0
# 4      23.448395            14.000582         0
#
# [5 rows x 44 columns]

# %% [markdown]
# You can also view rows in this dataset as a waterfall chart as follows:

# %%
from splink.charts import waterfall_chart
records_to_plot = df_e.to_dict(orient="records")
linker.waterfall_chart(records_to_plot, filter_nulls=False)
# Out:
# alt.LayerChart(...)

# %%
clusters = linker.cluster_pairwise_predictions_at_threshold(df_predict, threshold_match_probability=0.95)
# Out:
# Completed iteration 1, root rows count 661
# Completed iteration 2, root rows count 149
# Completed iteration 3, root rows count 43
# Completed iteration 4, root rows count 11
# Completed iteration 5, root rows count 3
# Completed iteration 6, root rows count 2
# Completed iteration 7, root rows count 1
# Completed iteration 8, root rows count 0

# %%
linker.cluster_studio_dashboard(df_predict, clusters, "dashboards/50k_cluster.html", sampling_method='by_cluster_size', overwrite=True)

from IPython.display import IFrame

IFrame(
    src="./dashboards/50k_cluster.html", width="100%", height=1200
)
# Out:
#         <iframe
#             width="100%"
#             height="1200"
#             src="./dashboards/50k_cluster.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
linker.roc_chart_from_labels_column("cluster",match_weight_round_to_nearest=0.02)
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# alt.Chart(...)

# %%
records = linker.prediction_errors_from_labels_column(
    "cluster",
    threshold=0.999,
    include_false_negatives=False,
    include_false_positives=True,
).as_record_dict()
linker.waterfall_chart(records)
# Out:
# alt.LayerChart(...)

# %%
# Some of the false negatives will be because they weren't detected by the blocking rules
records = linker.prediction_errors_from_labels_column(
    "cluster",
    threshold=0.5,
    include_false_negatives=True,
    include_false_positives=False,
).as_record_dict(limit=50)

linker.waterfall_chart(records)
# Out:
# alt.LayerChart(...)
